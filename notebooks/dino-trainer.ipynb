# %% [markdown]
# This notebook trains a classification model to predict 'tags' or 'severity' for the given Project Sidewalk label type.

# %%
import os
from copy import deepcopy
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch import nn, optim
import warnings
warnings.filterwarnings('ignore', category=UserWarning)
from torchvision import transforms, io
from dinov2.models.vision_transformer import vit_small, vit_base, vit_large, vit_giant2
import pandas as pd
from torch.utils.data import Dataset
from sklearn.metrics import accuracy_score

from comet_ml import Experiment
from comet_ml.integration.pytorch import log_model

# %%
# some initial variables

local_directory = os.getcwd()

# Enum for the classification categories we support.
C12N_CATEGORY = {
    'TAGS': 'tags',
    'SEVERITY': 'severity'
}

# this has to be consistent with the data generation script
c12n_category_offset = 8

# %%
# All the parameters that need to be configured for a training run should be in this cell.
# Everywhere else we will use these variables.

# classification category. currently, one of 'severity' or 'tags'.
c12n_category = C12N_CATEGORY['TAGS']
label_type = 'obstacle'
gsv_not_pannellum = True

image_dimension = 256

base_model_size = 'base'

# %%
# These are settings for ensuring input images to DinoV2 are properly sized

class ResizeAndPad:
    def __init__(self, target_size, multiple):
        self.target_size = target_size
        self.multiple = multiple

    def __call__(self, img):
        # Resize the image
        img = transforms.Resize(self.target_size)(img)

        # Calculate padding
        pad_width = (self.multiple - img.width % self.multiple) % self.multiple
        pad_height = (self.multiple - img.height % self.multiple) % self.multiple

        # Apply padding
        img = transforms.Pad((pad_width // 2, pad_height // 2, pad_width - pad_width // 2, pad_height - pad_height // 2))(img)

        return img

# This is what DinoV2 sees
target_size = (image_dimension, image_dimension)

# Below are functions that every image will be passed through, including data augmentations
data_transforms = {
    "train": transforms.Compose(
        [
            transforms.ToPILImage(),
            ResizeAndPad(target_size, 14),
            # transforms.RandomRotation(360),
            # transforms.RandomHorizontalFlip(),
            # transforms.RandomVerticalFlip(),
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
        ]
    ),
    "inference": transforms.Compose([ ResizeAndPad(target_size, 14),
                                               transforms.ToTensor(),
                                               transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
                                             ]
                                            )
}

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

if torch.cuda.is_available():
    print("GPU available")
else:
    print("GPU not available")
# Out:
# GPU available

# %%
def get_target_classes(dir_path, offset):
    file_path = os.path.join(dir_path, 'train.csv')
    data = pd.read_csv(file_path)
    header_row = data.columns.tolist()
    return header_row[offset:]

# %%
if gsv_not_pannellum:
    csv_data_dir_path_train = '../datasets/crops-' + label_type + '-' + c12n_category + '/train'
    model_name_to_save = 'cls-' + base_model_size[0] + '-' + label_type + '-' + c12n_category + '-best.pth'
else:
    csv_data_dir_path_train = '../datasets/crops-' + label_type + '-' + c12n_category + '-pannellum' + '/train'
    model_name_to_save = 'cls-' + base_model_size[0] + '-' + label_type + '-' + c12n_category + '-pannellum-best.pth'

model_name_to_save = 'dino-models/dino-' + model_name_to_save

print('Reading data from: ' + csv_data_dir_path_train)
print('Model name to save: ' + model_name_to_save)

# we will pass this to the model, so we don't have to change it manually
n_target_classes = len(get_target_classes(csv_data_dir_path_train, c12n_category_offset))
# Out:
# Reading data from: ../datasets/crops-obstacle-tags/train
# Model name to save: dino-models/dino-cls-b-obstacle-tags-best.pth

# %%
# Define a new classifier layer that contains a few linear layers with a ReLU to make predictions positive
class DinoVisionTransformerClassifier(nn.Module):

    def __init__(self, model_size="small", nc=1):
        super(DinoVisionTransformerClassifier, self).__init__()
        self.model_size = model_size

        # loading a model with registers
        n_register_tokens = 4

        if model_size == "small":
            model = vit_small(patch_size=14,
                              img_size=526,
                              init_values=1.0,
                              num_register_tokens=n_register_tokens,
                              block_chunks=0)
            self.embedding_size = 384
            self.number_of_heads = 6

        elif model_size == "base":
            model = vit_base(patch_size=14,
                             img_size=526,
                             init_values=1.0,
                             num_register_tokens=n_register_tokens,
                             block_chunks=0)
            self.embedding_size = 768
            self.number_of_heads = 12

        elif model_size == "large":
            model = vit_large(patch_size=14,
                              img_size=526,
                              init_values=1.0,
                              num_register_tokens=n_register_tokens,
                              block_chunks=0)
            self.embedding_size = 1024
            self.number_of_heads = 16

        elif model_size == "giant":
            model = vit_giant2(patch_size=14,
                               img_size=526,
                               init_values=1.0,
                               num_register_tokens=n_register_tokens,
                               block_chunks=0)
            self.embedding_size = 1536
            self.number_of_heads = 24
            
        self.model_name = 'dinov2-' + model_size

        # Download pre-trained weights and place locally as-needed:
        # - small: https://dl.fbaipublicfiles.com/dinov2/dinov2_vits14/dinov2_vits14_reg4_pretrain.pth
        # - base:  https://dl.fbaipublicfiles.com/dinov2/dinov2_vitb14/dinov2_vitb14_reg4_pretrain.pth
        # - large: https://dl.fbaipublicfiles.com/dinov2/dinov2_vitl14/dinov2_vitl14_reg4_pretrain.pth
        # - giant: https://dl.fbaipublicfiles.com/dinov2/dinov2_vitg14/dinov2_vitg14_reg4_pretrain.pth
        model.load_state_dict(torch.load(Path('{}/../dinov2_vit{}14_reg4_pretrain.pth'.format(local_directory, base_model_size[0]))))
        
        # # Training from  pretrained models
        # model.load_state_dict(torch.load(Path('{}/../dinov2_vit{}14_reg4_pretrain.pth'.format(local_directory, base_model_size[0]))))
        # state_dict = torch.load('{}/cls-{}-obstacle-tags-pannellum-best.pth'.format(local_directory, base_model_size[0]))
        # # state_dict = torch.load('{}/cls-{}-surfaceproblem-tags-pannellum-best.pth'.format(local_directory, base_model_size[0]))
        # remove_prefix = 'transformer.'
        # state_dict = {k[len(remove_prefix):] if k.startswith(remove_prefix) else k: v for k, v in state_dict.items()}
        # model.load_state_dict(state_dict, strict=False)  # strict=False ignores the classifier layers from the pannellum pretrained model

        self.transformer = deepcopy(model)


        # @zhihan, question: should the 256 be the same as the image resolution? or does it not matter?
        self.classifier = nn.Sequential(nn.Linear(self.embedding_size, 256), nn.ReLU(), nn.Linear(256, nc))

    def forward(self, x):
        x = self.transformer(x)
        x = self.transformer.norm(x)
        x = self.classifier(x)
        return x

model = DinoVisionTransformerClassifier(base_model_size, n_target_classes)

# %%
model = model.to(device)
model = model.train()
# change the binary cross-entropy loss below to a different loss if using more than 2 classes
# https://pytorch.org/docs/stable/nn.html#loss-functions

# @zhihan, question: are these loss functions correct?
if c12n_category == C12N_CATEGORY['TAGS']:
    criterion = nn.BCEWithLogitsLoss()
elif c12n_category == C12N_CATEGORY['SEVERITY']:
    criterion = nn.L1Loss()


optimizer = optim.Adam(model.parameters(), lr=1e-6)

num_epochs = 100

# experiment.log_parameters(hyper_params)

# %%
# custom data loader
class PSLabelsDataset(Dataset):
    """Face Landmarks dataset."""

    def __init__(self, csv_file, root_dir, offset=8, transform=None):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            offset (int, optional): number of columns to skip to get to the severity or tags info e.g. normalized_x and normalized_y need to be skipped.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.landmarks_frame = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transform = transform
        self.offset = offset

    def __len__(self):
        return len(self.landmarks_frame)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        img_name = os.path.join(self.root_dir,
                                self.landmarks_frame.iloc[idx, 0])
        image = io.read_image(img_name, mode=io.ImageReadMode.RGB)
        labels = self.landmarks_frame.iloc[idx, self.offset:]
        labels = np.array(labels)
        labels = labels.astype('float')
        # sample = {'image': image, 'labels': labels}

        if self.transform:
            image = self.transform(image)

        return image, labels

# %%
dataset = PSLabelsDataset(csv_data_dir_path_train + '/' + 'train.csv', root_dir=csv_data_dir_path_train, offset=c12n_category_offset, transform=data_transforms['train'])

print("Number of samples in the dataset: ", len(dataset))

dataloaders = {
    "train": torch.utils.data.DataLoader(dataset, batch_size=4, shuffle=True)
}
# Out:
# Number of samples in the dataset:  1954

# %%
# accuracy calculation for multilabel i.e. tags
def calculate_accuracy_multilabel(outputs, labels):
    # Convert outputs to probabilities using sigmoid
    probabilities = torch.sigmoid(outputs)
    # Convert probabilities to predicted classes
    predicted_classes = probabilities > 0.5
    # Calculate accuracy
    n_labels = labels.size(1)
    correct_predictions = ((predicted_classes == labels.byte()).sum().item()) / n_labels
    
    total_predictions = labels.size(0)
    
    return correct_predictions / total_predictions

# accuracy calculation for multiclass i.e. severity
def calculate_accuracy_multiclass(outputs, labels):
    # Convert outputs to probabilities using sigmoid
    probabilities = torch.softmax(outputs, 1)
    # Convert probabilities to predicted classes
    predicted_class_idx = torch.argmax(probabilities, 1).item()

    return int(labels[0][predicted_class_idx].item())

epoch_losses = []
epoch_accuracies = []

best_accuracy = 0
best_loss = 100

print("Training...")
for epoch in range(num_epochs):
    batch_losses = []
    batch_accuracies = []

    for data in dataloaders["train"]:
        # get the input batch and the ground truth labels
        batch_of_images, gt_labels = data

        # zero the parameter gradients
        optimizer.zero_grad()

        # model prediction
        output = model(batch_of_images.to(device)).squeeze(dim=1)
        
        # if c12n_category == C12N_CATEGORY['TAGS']:
        #     output = torch.sigmoid(output)
        
        if c12n_category == C12N_CATEGORY['SEVERITY']:
            output = torch.softmax(output, 1)

        # compute loss and do gradient descent
        loss = criterion(output, gt_labels.float().to(device))

        loss.backward()
        optimizer.step()

        batch_losses.append(loss.item())

        # Calculate and record batch accuracy
        
        accuracy = 0
        
        if c12n_category == C12N_CATEGORY['TAGS']:
            # accuracy = calculate_accuracy_multilabel(output, gt_labels.to(device))
            probabilities = torch.sigmoid(output)
            predicted_classes = (probabilities > 0.5).float()
            
        elif c12n_category == C12N_CATEGORY['SEVERITY']:
            # accuracy = calculate_accuracy_multiclass(output, gt_labels.to(device))
            probabilities = torch.softmax(output, 1)
            # Convert probabilities to predicted classes
            predicted_classes = torch.argmax(probabilities, 1)
        
        
        accuracy = accuracy_score(gt_labels.cpu().detach().numpy(), predicted_classes.cpu().detach().numpy())
        
        batch_accuracies.append(accuracy)

    epoch_losses.append(np.mean(batch_losses))
    epoch_accuracy = np.mean(batch_accuracies)
    epoch_loss = epoch_losses[-1]
    epoch_accuracies.append(epoch_accuracy)

    print("  -> Epoch {}: Loss = {:.5f}, Accuracy = {:.3f}%".format(epoch, epoch_losses[-1], 100*epoch_accuracy))
    
    # save the model if it has the best accuracy so far
    # @zhihan, should we be checking for accuracy at all? or should we just consider the model with the lowest loss as the best? 
    if epoch_accuracy > best_accuracy:
        best_accuracy = epoch_accuracy
        best_loss = epoch_loss
        torch.save(model.state_dict(), '{}/'.format(local_directory) + model_name_to_save)
        print('Saving model based on accuracy. Loss: {:.5f} | Accuracy: {:.3f}%'.format(best_loss, 100*best_accuracy))
    elif epoch_accuracy == best_accuracy:
        if epoch_loss < best_loss:
            best_loss = epoch_loss
            best_accuracy = epoch_accuracy
            torch.save(model.state_dict(), '{}/'.format(local_directory) + model_name_to_save)
            print('Saving model based on loss. Loss: {:.5f} | Accuracy: {:.3f}%'.format(best_loss, 100*best_accuracy))
            
    # # track on comet ml        
    # log_model(experiment, model_name_to_save, model)
# Out:
# Training...
#   -> Epoch 0: Loss = 0.35218, Accuracy = 0.511%
# Saving model based on accuracy. Loss: 0.35218 | Accuracy: 0.511%
#   -> Epoch 1: Loss = 0.22953, Accuracy = 1.227%
# Saving model based on accuracy. Loss: 0.22953 | Accuracy: 1.227%
#   -> Epoch 2: Loss = 0.20231, Accuracy = 9.305%
# Saving model based on accuracy. Loss: 0.20231 | Accuracy: 9.305%
#   -> Epoch 3: Loss = 0.18092, Accuracy = 22.393%
# Saving model based on accuracy. Loss: 0.18092 | Accuracy: 22.393%
#   -> Epoch 4: Loss = 0.16177, Accuracy = 30.726%
# Saving model based on accuracy. Loss: 0.16177 | Accuracy: 30.726%
#   -> Epoch 5: Loss = 0.14342, Accuracy = 39.519%
# Saving model based on accuracy. Loss: 0.14342 | Accuracy: 39.519%
#   -> Epoch 6: Loss = 0.12749, Accuracy = 44.939%
# Saving model based on accuracy. Loss: 0.12749 | Accuracy: 44.939%
#   -> Epoch 7: Loss = 0.11314, Accuracy = 48.108%
# Saving model based on accuracy. Loss: 0.11314 | Accuracy: 48.108%
#   -> Epoch 8: Loss = 0.10090, Accuracy = 50.920%
# Saving model based on accuracy. Loss: 0.10090 | Accuracy: 50.920%
#   -> Epoch 9: Loss = 0.09001, Accuracy = 57.004%
# Saving model based on accuracy. Loss: 0.09001 | Accuracy: 57.004%
#   -> Epoch 10: Loss = 0.07986, Accuracy = 62.423%
# Saving model based on accuracy. Loss: 0.07986 | Accuracy: 62.423%
#   -> Epoch 11: Loss = 0.07060, Accuracy = 68.814%
# Saving model based on accuracy. Loss: 0.07060 | Accuracy: 68.814%
#   -> Epoch 12: Loss = 0.06167, Accuracy = 75.102%
# Saving model based on accuracy. Loss: 0.06167 | Accuracy: 75.102%
#   -> Epoch 13: Loss = 0.05344, Accuracy = 81.902%
# Saving model based on accuracy. Loss: 0.05344 | Accuracy: 81.902%
#   -> Epoch 14: Loss = 0.04554, Accuracy = 89.110%
# Saving model based on accuracy. Loss: 0.04554 | Accuracy: 89.110%
#   -> Epoch 15: Loss = 0.03953, Accuracy = 90.798%
# Saving model based on accuracy. Loss: 0.03953 | Accuracy: 90.798%
#   -> Epoch 16: Loss = 0.03444, Accuracy = 93.354%
# Saving model based on accuracy. Loss: 0.03444 | Accuracy: 93.354%
#   -> Epoch 17: Loss = 0.03020, Accuracy = 94.223%
# Saving model based on accuracy. Loss: 0.03020 | Accuracy: 94.223%
#   -> Epoch 18: Loss = 0.02679, Accuracy = 95.092%
# Saving model based on accuracy. Loss: 0.02679 | Accuracy: 95.092%
#   -> Epoch 19: Loss = 0.02356, Accuracy = 95.757%
# Saving model based on accuracy. Loss: 0.02356 | Accuracy: 95.757%
#   -> Epoch 20: Loss = 0.02124, Accuracy = 96.575%
# Saving model based on accuracy. Loss: 0.02124 | Accuracy: 96.575%
#   -> Epoch 21: Loss = 0.01910, Accuracy = 97.035%
# Saving model based on accuracy. Loss: 0.01910 | Accuracy: 97.035%
#   -> Epoch 22: Loss = 0.01761, Accuracy = 97.342%
# Saving model based on accuracy. Loss: 0.01761 | Accuracy: 97.342%
#   -> Epoch 23: Loss = 0.01559, Accuracy = 97.853%
# Saving model based on accuracy. Loss: 0.01559 | Accuracy: 97.853%
#   -> Epoch 24: Loss = 0.01399, Accuracy = 98.057%
# Saving model based on accuracy. Loss: 0.01399 | Accuracy: 98.057%
#   -> Epoch 25: Loss = 0.01289, Accuracy = 98.160%
# Saving model based on accuracy. Loss: 0.01289 | Accuracy: 98.160%
#   -> Epoch 26: Loss = 0.01179, Accuracy = 98.620%
# Saving model based on accuracy. Loss: 0.01179 | Accuracy: 98.620%
#   -> Epoch 27: Loss = 0.01114, Accuracy = 98.057%
#   -> Epoch 28: Loss = 0.01001, Accuracy = 98.364%
#   -> Epoch 29: Loss = 0.00893, Accuracy = 99.029%
# Saving model based on accuracy. Loss: 0.00893 | Accuracy: 99.029%
#   -> Epoch 30: Loss = 0.00780, Accuracy = 99.335%
# Saving model based on accuracy. Loss: 0.00780 | Accuracy: 99.335%
#   -> Epoch 31: Loss = 0.00732, Accuracy = 99.131%
#   -> Epoch 32: Loss = 0.00784, Accuracy = 98.671%
#   -> Epoch 33: Loss = 0.00665, Accuracy = 98.926%
#   -> Epoch 34: Loss = 0.00582, Accuracy = 99.489%
# Saving model based on accuracy. Loss: 0.00582 | Accuracy: 99.489%
#   -> Epoch 35: Loss = 0.00530, Accuracy = 99.591%
# Saving model based on accuracy. Loss: 0.00530 | Accuracy: 99.591%
#   -> Epoch 36: Loss = 0.00505, Accuracy = 99.438%
#   -> Epoch 37: Loss = 0.00480, Accuracy = 99.387%
#   -> Epoch 38: Loss = 0.00467, Accuracy = 99.387%
#   -> Epoch 39: Loss = 0.00631, Accuracy = 98.671%
#   -> Epoch 40: Loss = 0.00436, Accuracy = 99.591%
# Saving model based on loss. Loss: 0.00436 | Accuracy: 99.591%
#   -> Epoch 41: Loss = 0.00333, Accuracy = 99.949%
# Saving model based on accuracy. Loss: 0.00333 | Accuracy: 99.949%
#   -> Epoch 42: Loss = 0.00296, Accuracy = 99.949%
# Saving model based on loss. Loss: 0.00296 | Accuracy: 99.949%
#   -> Epoch 43: Loss = 0.00274, Accuracy = 99.949%
# Saving model based on loss. Loss: 0.00274 | Accuracy: 99.949%
#   -> Epoch 44: Loss = 0.00263, Accuracy = 100.000%
# Saving model based on accuracy. Loss: 0.00263 | Accuracy: 100.000%
#   -> Epoch 45: Loss = 0.00498, Accuracy = 98.466%
#   -> Epoch 46: Loss = 0.00462, Accuracy = 98.926%
#   -> Epoch 47: Loss = 0.00272, Accuracy = 99.847%
#   -> Epoch 48: Loss = 0.00222, Accuracy = 99.949%
#   -> Epoch 49: Loss = 0.00201, Accuracy = 100.000%
# Saving model based on loss. Loss: 0.00201 | Accuracy: 100.000%
#   -> Epoch 50: Loss = 0.00185, Accuracy = 99.949%
#   -> Epoch 51: Loss = 0.00175, Accuracy = 100.000%
# Saving model based on loss. Loss: 0.00175 | Accuracy: 100.000%
#   -> Epoch 52: Loss = 0.00173, Accuracy = 99.949%
#   -> Epoch 53: Loss = 0.00182, Accuracy = 99.898%
#   -> Epoch 54: Loss = 0.00630, Accuracy = 97.393%
#   -> Epoch 55: Loss = 0.00266, Accuracy = 99.591%
#   -> Epoch 56: Loss = 0.00172, Accuracy = 99.949%
#   -> Epoch 57: Loss = 0.00144, Accuracy = 100.000%
# Saving model based on loss. Loss: 0.00144 | Accuracy: 100.000%
#   -> Epoch 58: Loss = 0.00132, Accuracy = 100.000%
# Saving model based on loss. Loss: 0.00132 | Accuracy: 100.000%
#   -> Epoch 59: Loss = 0.00122, Accuracy = 100.000%
# Saving model based on loss. Loss: 0.00122 | Accuracy: 100.000%
#   -> Epoch 60: Loss = 0.00115, Accuracy = 100.000%
# Saving model based on loss. Loss: 0.00115 | Accuracy: 100.000%
#   -> Epoch 61: Loss = 0.00108, Accuracy = 100.000%
# Saving model based on loss. Loss: 0.00108 | Accuracy: 100.000%
#   -> Epoch 62: Loss = 0.00105, Accuracy = 99.949%
#   -> Epoch 63: Loss = 0.00217, Accuracy = 99.438%
#   -> Epoch 64: Loss = 0.00350, Accuracy = 98.773%
#   -> Epoch 65: Loss = 0.00137, Accuracy = 100.000%
#   -> Epoch 66: Loss = 0.00103, Accuracy = 100.000%
# Saving model based on loss. Loss: 0.00103 | Accuracy: 100.000%
#   -> Epoch 67: Loss = 0.00092, Accuracy = 100.000%
# Saving model based on loss. Loss: 0.00092 | Accuracy: 100.000%
#   -> Epoch 68: Loss = 0.00085, Accuracy = 100.000%
# Saving model based on loss. Loss: 0.00085 | Accuracy: 100.000%
#   -> Epoch 69: Loss = 0.00079, Accuracy = 100.000%
# Saving model based on loss. Loss: 0.00079 | Accuracy: 100.000%
#   -> Epoch 70: Loss = 0.00075, Accuracy = 100.000%
# Saving model based on loss. Loss: 0.00075 | Accuracy: 100.000%
#   -> Epoch 71: Loss = 0.00072, Accuracy = 100.000%
# Saving model based on loss. Loss: 0.00072 | Accuracy: 100.000%
#   -> Epoch 72: Loss = 0.00259, Accuracy = 99.080%
#   -> Epoch 73: Loss = 0.00274, Accuracy = 99.131%
#   -> Epoch 74: Loss = 0.00114, Accuracy = 99.898%
#   -> Epoch 75: Loss = 0.00079, Accuracy = 100.000%
#   -> Epoch 76: Loss = 0.00070, Accuracy = 100.000%
# Saving model based on loss. Loss: 0.00070 | Accuracy: 100.000%
#   -> Epoch 77: Loss = 0.00065, Accuracy = 100.000%
# Saving model based on loss. Loss: 0.00065 | Accuracy: 100.000%
#   -> Epoch 78: Loss = 0.00060, Accuracy = 100.000%
# Saving model based on loss. Loss: 0.00060 | Accuracy: 100.000%
#   -> Epoch 79: Loss = 0.00057, Accuracy = 100.000%
# Saving model based on loss. Loss: 0.00057 | Accuracy: 100.000%
#   -> Epoch 80: Loss = 0.00053, Accuracy = 100.000%
# Saving model based on loss. Loss: 0.00053 | Accuracy: 100.000%
#   -> Epoch 81: Loss = 0.00050, Accuracy = 100.000%
# Saving model based on loss. Loss: 0.00050 | Accuracy: 100.000%
#   -> Epoch 82: Loss = 0.00052, Accuracy = 100.000%
#   -> Epoch 83: Loss = 0.00428, Accuracy = 98.006%
#   -> Epoch 84: Loss = 0.00170, Accuracy = 99.387%
#   -> Epoch 85: Loss = 0.00068, Accuracy = 100.000%
#   -> Epoch 86: Loss = 0.00056, Accuracy = 100.000%
#   -> Epoch 87: Loss = 0.00051, Accuracy = 100.000%
#   -> Epoch 88: Loss = 0.00047, Accuracy = 100.000%
# Saving model based on loss. Loss: 0.00047 | Accuracy: 100.000%
#   -> Epoch 89: Loss = 0.00044, Accuracy = 100.000%
# Saving model based on loss. Loss: 0.00044 | Accuracy: 100.000%
#   -> Epoch 90: Loss = 0.00042, Accuracy = 100.000%
# Saving model based on loss. Loss: 0.00042 | Accuracy: 100.000%
#   -> Epoch 91: Loss = 0.00039, Accuracy = 100.000%
# Saving model based on loss. Loss: 0.00039 | Accuracy: 100.000%
#   -> Epoch 92: Loss = 0.00037, Accuracy = 100.000%
# Saving model based on loss. Loss: 0.00037 | Accuracy: 100.000%
#   -> Epoch 93: Loss = 0.00035, Accuracy = 100.000%
# Saving model based on loss. Loss: 0.00035 | Accuracy: 100.000%
#   -> Epoch 94: Loss = 0.00035, Accuracy = 100.000%
#   -> Epoch 95: Loss = 0.00481, Accuracy = 98.006%
#   -> Epoch 96: Loss = 0.00098, Accuracy = 99.693%
#   -> Epoch 97: Loss = 0.00052, Accuracy = 100.000%
#   -> Epoch 98: Loss = 0.00040, Accuracy = 100.000%
#   -> Epoch 99: Loss = 0.00036, Accuracy = 100.000%

# %%
# Plotting accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(epoch_accuracies, label='Accuracy', color='blue')
plt.title("Training Accuracy")
plt.xlabel("Epoch Number")
plt.ylabel("Accuracy")

# Plotting loss
plt.subplot(1, 2, 2)
plt.plot(epoch_losses, label='Loss', color='red')
plt.title("Training Loss")
plt.xlabel("Epoch Number")
plt.ylabel("Loss")

plt.savefig(model_name_to_save.replace('.pth', '') + '-training_plot.png')

plt.show()
