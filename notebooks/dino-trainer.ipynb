# %% [markdown]
# This notebook trains a classification model to predict 'tags' or 'severity' for the given Project Sidewalk label type.

# %%
import os
import time
from copy import deepcopy
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch import nn, optim
import warnings
warnings.filterwarnings('ignore', category=UserWarning)
from torchvision import transforms, io
from dinov2.models.vision_transformer import vit_small, vit_base, vit_large, vit_giant2
import pandas as pd
from torch.utils.data import Dataset
from sklearn.metrics import accuracy_score

from comet_ml import Experiment
from comet_ml.integration.pytorch import log_model

# %%
# some initial variables

local_directory = os.getcwd()

# Enum for the classification categories we support.
C12N_CATEGORY = {
    'TAGS': 'tags',
    'SEVERITY': 'severity'
}

# this has to be consistent with the data generation script
c12n_category_offset = 8

# %%
# All the parameters that need to be configured for a training run should be in this cell.
# Everywhere else we will use these variables.

# classification category. currently, one of 'severity' or 'tags'.

label_type = 'surfaceproblem'
dataset_group = 'validated'


c12n_category = C12N_CATEGORY['TAGS']
gsv_not_pannellum = True
image_dimension = 256
base_model_size = 'base'

# %%
# These are settings for ensuring input images to DinoV2 are properly sized

class ResizeAndPad:
    def __init__(self, target_size, multiple):
        self.target_size = target_size
        self.multiple = multiple

    def __call__(self, img):
        # Resize the image
        img = transforms.Resize(self.target_size)(img)

        # Calculate padding
        pad_width = (self.multiple - img.width % self.multiple) % self.multiple
        pad_height = (self.multiple - img.height % self.multiple) % self.multiple

        # Apply padding
        img = transforms.Pad((pad_width // 2, pad_height // 2, pad_width - pad_width // 2, pad_height - pad_height // 2))(img)

        return img

# This is what DinoV2 sees
target_size = (image_dimension, image_dimension)

# Below are functions that every image will be passed through, including data augmentations
data_transforms = {
    "train": transforms.Compose(
        [
            transforms.ToPILImage(),
            ResizeAndPad(target_size, 14),
            # transforms.RandomRotation(360),
            # transforms.RandomHorizontalFlip(),
            # transforms.RandomVerticalFlip(),
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
        ]
    ),
    "inference": transforms.Compose([ ResizeAndPad(target_size, 14),
                                               transforms.ToTensor(),
                                               transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
                                             ]
                                            )
}

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

if torch.cuda.is_available():
    print("GPU available")
else:
    print("GPU not available")
# Out:
# GPU available

# %%
def get_target_classes(dir_path, offset):
    file_path = os.path.join(dir_path, 'train.csv')
    data = pd.read_csv(file_path)
    header_row = data.columns.tolist()
    return header_row[offset:]

# %%
if gsv_not_pannellum:
    csv_data_dir_path_train = '../datasets-' + dataset_group + '/crops-' + label_type + '-' + c12n_category + '/train'
    model_name_to_save = 'cls-' + base_model_size[0] + '-' + label_type + '-' + c12n_category + '-best.pth'
else:
    csv_data_dir_path_train = '../datasets-' + dataset_group + '/crops-' + label_type + '-' + c12n_category + '-pannellum' + '/train'
    model_name_to_save = 'cls-' + base_model_size[0] + '-' + label_type + '-' + c12n_category + '-pannellum-best.pth'

model_name_to_save = 'dino-models/' + dataset_group + '-dino-' + model_name_to_save

print('Reading data from: ' + csv_data_dir_path_train)
print('Model name to save: ' + model_name_to_save)

# we will pass this to the model, so we don't have to change it manually
n_target_classes = len(get_target_classes(csv_data_dir_path_train, c12n_category_offset))
# Out:
# Reading data from: ../datasets-validated/crops-surfaceproblem-tags/train
# Model name to save: dino-models/validated-dino-cls-b-surfaceproblem-tags-best.pth

# %%
# Define a new classifier layer that contains a few linear layers with a ReLU to make predictions positive
class DinoVisionTransformerClassifier(nn.Module):

    def __init__(self, model_size="small", nc=1):
        super(DinoVisionTransformerClassifier, self).__init__()
        self.model_size = model_size

        # loading a model with registers
        n_register_tokens = 4

        if model_size == "small":
            model = vit_small(patch_size=14,
                              img_size=526,
                              init_values=1.0,
                              num_register_tokens=n_register_tokens,
                              block_chunks=0)
            self.embedding_size = 384
            self.number_of_heads = 6

        elif model_size == "base":
            model = vit_base(patch_size=14,
                             img_size=526,
                             init_values=1.0,
                             num_register_tokens=n_register_tokens,
                             block_chunks=0)
            self.embedding_size = 768
            self.number_of_heads = 12

        elif model_size == "large":
            model = vit_large(patch_size=14,
                              img_size=526,
                              init_values=1.0,
                              num_register_tokens=n_register_tokens,
                              block_chunks=0)
            self.embedding_size = 1024
            self.number_of_heads = 16

        elif model_size == "giant":
            model = vit_giant2(patch_size=14,
                               img_size=526,
                               init_values=1.0,
                               num_register_tokens=n_register_tokens,
                               block_chunks=0)
            self.embedding_size = 1536
            self.number_of_heads = 24
            
        self.model_name = 'dinov2-' + model_size

        # Download pre-trained weights and place locally as-needed:
        # - small: https://dl.fbaipublicfiles.com/dinov2/dinov2_vits14/dinov2_vits14_reg4_pretrain.pth
        # - base:  https://dl.fbaipublicfiles.com/dinov2/dinov2_vitb14/dinov2_vitb14_reg4_pretrain.pth
        # - large: https://dl.fbaipublicfiles.com/dinov2/dinov2_vitl14/dinov2_vitl14_reg4_pretrain.pth
        # - giant: https://dl.fbaipublicfiles.com/dinov2/dinov2_vitg14/dinov2_vitg14_reg4_pretrain.pth
        model.load_state_dict(torch.load(Path('{}/../dinov2_vit{}14_reg4_pretrain.pth'.format(local_directory, base_model_size[0]))))
        
        # # Training from  pretrained models
        # model.load_state_dict(torch.load(Path('{}/../dinov2_vit{}14_reg4_pretrain.pth'.format(local_directory, base_model_size[0]))))
        # state_dict = torch.load('{}/cls-{}-obstacle-tags-pannellum-best.pth'.format(local_directory, base_model_size[0]))
        # # state_dict = torch.load('{}/cls-{}-surfaceproblem-tags-pannellum-best.pth'.format(local_directory, base_model_size[0]))
        # remove_prefix = 'transformer.'
        # state_dict = {k[len(remove_prefix):] if k.startswith(remove_prefix) else k: v for k, v in state_dict.items()}
        # model.load_state_dict(state_dict, strict=False)  # strict=False ignores the classifier layers from the pannellum pretrained model

        self.transformer = deepcopy(model)


        # @zhihan, question: should the 256 be the same as the image resolution? or does it not matter?
        self.classifier = nn.Sequential(nn.Linear(self.embedding_size, 256), nn.ReLU(), nn.Linear(256, nc))

    def forward(self, x):
        x = self.transformer(x)
        x = self.transformer.norm(x)
        x = self.classifier(x)
        return x

model = DinoVisionTransformerClassifier(base_model_size, n_target_classes)

# %%
model = model.to(device)
model = model.train()
# change the binary cross-entropy loss below to a different loss if using more than 2 classes
# https://pytorch.org/docs/stable/nn.html#loss-functions

# @zhihan, question: are these loss functions correct?
if c12n_category == C12N_CATEGORY['TAGS']:
    criterion = nn.BCEWithLogitsLoss()
elif c12n_category == C12N_CATEGORY['SEVERITY']:
    criterion = nn.L1Loss()


optimizer = optim.Adam(model.parameters(), lr=1e-6)

num_epochs = 100

# experiment.log_parameters(hyper_params)

# %%
# custom data loader
class PSLabelsDataset(Dataset):
    """Face Landmarks dataset."""

    def __init__(self, csv_file, root_dir, offset=8, transform=None):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            offset (int, optional): number of columns to skip to get to the severity or tags info e.g. normalized_x and normalized_y need to be skipped.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.landmarks_frame = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transform = transform
        self.offset = offset

    def __len__(self):
        return len(self.landmarks_frame)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        img_name = os.path.join(self.root_dir,
                                self.landmarks_frame.iloc[idx, 0])
        image = io.read_image(img_name, mode=io.ImageReadMode.RGB)
        
        
        labels = self.landmarks_frame.iloc[idx, self.offset:]
        labels = np.array(labels)
        labels = labels.astype('float')
        # sample = {'image': image, 'labels': labels}

        if self.transform:
            image = self.transform(image)

        return image, labels

# %%
dataset = PSLabelsDataset(csv_data_dir_path_train + '/' + 'train.csv', root_dir=csv_data_dir_path_train, offset=c12n_category_offset, transform=data_transforms['train'])

print("Number of samples in the dataset: ", len(dataset))

dataloaders = {
    "train": torch.utils.data.DataLoader(dataset, batch_size=4, shuffle=True)
}
# Out:
# Number of samples in the dataset:  7282

# %%
epoch_losses = []
epoch_accuracies = []

best_accuracy = 0
best_loss = 100

start_time = time.time()

print("Training...")
for epoch in range(num_epochs):
    batch_losses = []
    batch_accuracies = []

    epoch_start_time = time.time()

    for data in dataloaders["train"]:
        # get the input batch and the ground truth labels
        batch_of_images, gt_labels = data

        # zero the parameter gradients
        optimizer.zero_grad()

        # model prediction
        output = model(batch_of_images.to(device)).squeeze(dim=1)
        
        # if c12n_category == C12N_CATEGORY['TAGS']:
        #     output = torch.sigmoid(output)
        
        if c12n_category == C12N_CATEGORY['SEVERITY']:
            output = torch.softmax(output, 1)

        # compute loss and do gradient descent
        loss = criterion(output, gt_labels.float().to(device))

        loss.backward()
        optimizer.step()

        batch_losses.append(loss.item())

        # Calculate and record batch accuracy
        
        accuracy = 0
        
        if c12n_category == C12N_CATEGORY['TAGS']:
            probabilities = torch.sigmoid(output)
            predicted_classes = (probabilities > 0.5).float()
            
        elif c12n_category == C12N_CATEGORY['SEVERITY']:
            probabilities = torch.softmax(output, 1)
            # Convert probabilities to predicted classes
            predicted_classes = torch.argmax(probabilities, 1)
        
        
        accuracy = accuracy_score(gt_labels.cpu().detach().numpy(), predicted_classes.cpu().detach().numpy())
        
        batch_accuracies.append(accuracy)
        
        
    epoch_end_time = time.time()
    print("Epoch {} took {:.0f}m {:.0f}s".format(epoch, (epoch_end_time - epoch_start_time) // 60, (epoch_end_time - epoch_start_time) % 60))

    epoch_losses.append(np.mean(batch_losses))
    epoch_accuracy = np.mean(batch_accuracies)
    epoch_loss = epoch_losses[-1]
    epoch_accuracies.append(epoch_accuracy)

    print("  -> Epoch {}: Loss = {:.5f}, Accuracy = {:.3f}%".format(epoch, epoch_losses[-1], 100*epoch_accuracy))
    
    # save the model if it has the best accuracy so far
    # @zhihan, should we be checking for accuracy at all? or should we just consider the model with the lowest loss as the best? 
    if epoch_accuracy > best_accuracy:
        best_accuracy = epoch_accuracy
        best_loss = epoch_loss
        torch.save(model.state_dict(), '{}/'.format(local_directory) + model_name_to_save)
        print('Saving model based on accuracy. Loss: {:.5f} | Accuracy: {:.3f}%'.format(best_loss, 100*best_accuracy))
    elif epoch_accuracy == best_accuracy:
        if epoch_loss < best_loss:
            best_loss = epoch_loss
            best_accuracy = epoch_accuracy
            torch.save(model.state_dict(), '{}/'.format(local_directory) + model_name_to_save)
            print('Saving model based on loss. Loss: {:.5f} | Accuracy: {:.3f}%'.format(best_loss, 100*best_accuracy))
            
            
end_time = time.time()

elapsed_time = end_time - start_time
print("Training complete in {:.0f}m {:.0f}s".format(elapsed_time // 60, elapsed_time % 60))
# Out:
# Training...
# Epoch 0 took 6m 41s
#   -> Epoch 0: Loss = 0.29755, Accuracy = 10.791%
# Saving model based on accuracy. Loss: 0.29755 | Accuracy: 10.791%
# Epoch 1 took 6m 41s
#   -> Epoch 1: Loss = 0.21956, Accuracy = 29.599%
# Saving model based on accuracy. Loss: 0.21956 | Accuracy: 29.599%
# Epoch 2 took 6m 40s
#   -> Epoch 2: Loss = 0.18576, Accuracy = 40.362%
# Saving model based on accuracy. Loss: 0.18576 | Accuracy: 40.362%
# Epoch 3 took 6m 41s
#   -> Epoch 3: Loss = 0.16273, Accuracy = 46.650%
# Saving model based on accuracy. Loss: 0.16273 | Accuracy: 46.650%
# Epoch 4 took 6m 41s
#   -> Epoch 4: Loss = 0.14238, Accuracy = 52.361%
# Saving model based on accuracy. Loss: 0.14238 | Accuracy: 52.361%
# Epoch 5 took 6m 41s
#   -> Epoch 5: Loss = 0.12356, Accuracy = 58.663%
# Saving model based on accuracy. Loss: 0.12356 | Accuracy: 58.663%
# Epoch 6 took 6m 41s
#   -> Epoch 6: Loss = 0.10536, Accuracy = 66.021%
# Saving model based on accuracy. Loss: 0.10536 | Accuracy: 66.021%
# Epoch 7 took 6m 41s
#   -> Epoch 7: Loss = 0.08845, Accuracy = 72.721%
# Saving model based on accuracy. Loss: 0.08845 | Accuracy: 72.721%
# Epoch 8 took 6m 41s
#   -> Epoch 8: Loss = 0.07246, Accuracy = 79.187%
# Saving model based on accuracy. Loss: 0.07246 | Accuracy: 79.187%
# Epoch 9 took 6m 41s
#   -> Epoch 9: Loss = 0.05845, Accuracy = 84.061%
# Saving model based on accuracy. Loss: 0.05845 | Accuracy: 84.061%
# Epoch 10 took 6m 41s
#   -> Epoch 10: Loss = 0.04636, Accuracy = 88.688%
# Saving model based on accuracy. Loss: 0.04636 | Accuracy: 88.688%
# Epoch 11 took 6m 41s
#   -> Epoch 11: Loss = 0.03688, Accuracy = 92.010%
# Saving model based on accuracy. Loss: 0.03688 | Accuracy: 92.010%
# Epoch 12 took 6m 41s
#   -> Epoch 12: Loss = 0.02913, Accuracy = 94.179%
# Saving model based on accuracy. Loss: 0.02913 | Accuracy: 94.179%
# Epoch 13 took 6m 41s
#   -> Epoch 13: Loss = 0.02334, Accuracy = 95.497%
# Saving model based on accuracy. Loss: 0.02334 | Accuracy: 95.497%
# Epoch 14 took 6m 41s
#   -> Epoch 14: Loss = 0.01903, Accuracy = 96.636%
# Saving model based on accuracy. Loss: 0.01903 | Accuracy: 96.636%
# Epoch 15 took 6m 41s
#   -> Epoch 15: Loss = 0.01613, Accuracy = 97.268%
# Saving model based on accuracy. Loss: 0.01613 | Accuracy: 97.268%
# Epoch 16 took 6m 42s
#   -> Epoch 16: Loss = 0.01316, Accuracy = 97.790%
# Saving model based on accuracy. Loss: 0.01316 | Accuracy: 97.790%
# Epoch 17 took 6m 41s
#   -> Epoch 17: Loss = 0.01138, Accuracy = 98.353%
# Saving model based on accuracy. Loss: 0.01138 | Accuracy: 98.353%
# Epoch 18 took 6m 41s
#   -> Epoch 18: Loss = 0.00932, Accuracy = 98.723%
# Saving model based on accuracy. Loss: 0.00932 | Accuracy: 98.723%
# Epoch 19 took 6m 41s
#   -> Epoch 19: Loss = 0.00843, Accuracy = 98.806%
# Saving model based on accuracy. Loss: 0.00843 | Accuracy: 98.806%
# Epoch 20 took 6m 41s
#   -> Epoch 20: Loss = 0.00671, Accuracy = 99.231%
# Saving model based on accuracy. Loss: 0.00671 | Accuracy: 99.231%
# Epoch 21 took 6m 41s
#   -> Epoch 21: Loss = 0.00592, Accuracy = 99.341%
# Saving model based on accuracy. Loss: 0.00592 | Accuracy: 99.341%
# Epoch 22 took 6m 41s
#   -> Epoch 22: Loss = 0.00556, Accuracy = 99.231%
# Epoch 23 took 6m 41s
#   -> Epoch 23: Loss = 0.00556, Accuracy = 99.190%
# Epoch 24 took 6m 41s
#   -> Epoch 24: Loss = 0.00400, Accuracy = 99.602%
# Saving model based on accuracy. Loss: 0.00400 | Accuracy: 99.602%
# Epoch 25 took 6m 41s
#   -> Epoch 25: Loss = 0.00324, Accuracy = 99.698%
# Saving model based on accuracy. Loss: 0.00324 | Accuracy: 99.698%
# Epoch 26 took 6m 41s
#   -> Epoch 26: Loss = 0.00322, Accuracy = 99.657%
# Epoch 27 took 6m 41s
#   -> Epoch 27: Loss = 0.00359, Accuracy = 99.533%
# Epoch 28 took 6m 40s
#   -> Epoch 28: Loss = 0.00301, Accuracy = 99.657%
# Epoch 29 took 6m 41s
#   -> Epoch 29: Loss = 0.00207, Accuracy = 99.890%
# Saving model based on accuracy. Loss: 0.00207 | Accuracy: 99.890%
# Epoch 30 took 6m 41s
#   -> Epoch 30: Loss = 0.00215, Accuracy = 99.835%
# Epoch 31 took 6m 41s
#   -> Epoch 31: Loss = 0.00275, Accuracy = 99.588%
# Epoch 32 took 6m 41s
#   -> Epoch 32: Loss = 0.00257, Accuracy = 99.547%
# Epoch 33 took 6m 40s
#   -> Epoch 33: Loss = 0.00231, Accuracy = 99.698%
# Epoch 34 took 6m 41s
#   -> Epoch 34: Loss = 0.00258, Accuracy = 99.492%
# Epoch 35 took 6m 41s
#   -> Epoch 35: Loss = 0.00176, Accuracy = 99.808%
# Epoch 36 took 6m 41s
#   -> Epoch 36: Loss = 0.00186, Accuracy = 99.725%
# Epoch 37 took 6m 41s
#   -> Epoch 37: Loss = 0.00132, Accuracy = 99.876%
# Epoch 38 took 6m 41s
#   -> Epoch 38: Loss = 0.00232, Accuracy = 99.451%
# Epoch 39 took 6m 41s
#   -> Epoch 39: Loss = 0.00161, Accuracy = 99.725%
# Epoch 40 took 6m 41s
#   -> Epoch 40: Loss = 0.00130, Accuracy = 99.863%
# Epoch 41 took 6m 40s
#   -> Epoch 41: Loss = 0.00224, Accuracy = 99.451%
# Epoch 42 took 6m 40s
#   -> Epoch 42: Loss = 0.00156, Accuracy = 99.794%
# Epoch 43 took 6m 41s
#   -> Epoch 43: Loss = 0.00144, Accuracy = 99.739%
# Epoch 44 took 6m 41s
#   -> Epoch 44: Loss = 0.00106, Accuracy = 99.890%
# Saving model based on loss. Loss: 0.00106 | Accuracy: 99.890%
# Epoch 45 took 6m 41s
#   -> Epoch 45: Loss = 0.00095, Accuracy = 99.931%
# Saving model based on accuracy. Loss: 0.00095 | Accuracy: 99.931%
# Epoch 46 took 6m 41s
#   -> Epoch 46: Loss = 0.00196, Accuracy = 99.423%
# Epoch 47 took 6m 40s
#   -> Epoch 47: Loss = 0.00144, Accuracy = 99.780%
# Epoch 48 took 6m 41s
#   -> Epoch 48: Loss = 0.00066, Accuracy = 99.973%
# Saving model based on accuracy. Loss: 0.00066 | Accuracy: 99.973%
# Epoch 49 took 6m 41s
#   -> Epoch 49: Loss = 0.00130, Accuracy = 99.835%
# Epoch 50 took 6m 41s
#   -> Epoch 50: Loss = 0.00200, Accuracy = 99.410%
# Epoch 51 took 6m 40s
#   -> Epoch 51: Loss = 0.00123, Accuracy = 99.794%
# Epoch 52 took 6m 41s
#   -> Epoch 52: Loss = 0.00147, Accuracy = 99.712%
# Epoch 53 took 6m 42s
#   -> Epoch 53: Loss = 0.00150, Accuracy = 99.698%
# Epoch 54 took 6m 42s
#   -> Epoch 54: Loss = 0.00147, Accuracy = 99.712%
# Epoch 55 took 6m 42s
#   -> Epoch 55: Loss = 0.00098, Accuracy = 99.808%
# Epoch 56 took 6m 48s
#   -> Epoch 56: Loss = 0.00142, Accuracy = 99.780%
# Epoch 57 took 6m 43s
#   -> Epoch 57: Loss = 0.00151, Accuracy = 99.643%
# Epoch 58 took 6m 43s
#   -> Epoch 58: Loss = 0.00099, Accuracy = 99.808%
# Epoch 59 took 6m 45s
#   -> Epoch 59: Loss = 0.00081, Accuracy = 99.876%
# Epoch 60 took 6m 43s
#   -> Epoch 60: Loss = 0.00099, Accuracy = 99.863%
# Epoch 61 took 6m 47s
#   -> Epoch 61: Loss = 0.00108, Accuracy = 99.794%
# Epoch 62 took 6m 46s
#   -> Epoch 62: Loss = 0.00086, Accuracy = 99.822%
# Epoch 63 took 6m 44s
#   -> Epoch 63: Loss = 0.00170, Accuracy = 99.588%
# Epoch 64 took 6m 43s
#   -> Epoch 64: Loss = 0.00104, Accuracy = 99.698%
# Epoch 65 took 6m 41s
#   -> Epoch 65: Loss = 0.00127, Accuracy = 99.671%
# Epoch 66 took 6m 47s
#   -> Epoch 66: Loss = 0.00095, Accuracy = 99.808%
# Epoch 67 took 6m 44s
#   -> Epoch 67: Loss = 0.00113, Accuracy = 99.739%
# Epoch 68 took 6m 46s
#   -> Epoch 68: Loss = 0.00058, Accuracy = 99.945%
# Epoch 69 took 6m 44s
#   -> Epoch 69: Loss = 0.00116, Accuracy = 99.602%
# Epoch 70 took 6m 43s
#   -> Epoch 70: Loss = 0.00145, Accuracy = 99.629%
# Epoch 71 took 6m 41s
#   -> Epoch 71: Loss = 0.00085, Accuracy = 99.835%
# Epoch 72 took 6m 42s
#   -> Epoch 72: Loss = 0.00113, Accuracy = 99.698%
# Epoch 73 took 6m 42s
#   -> Epoch 73: Loss = 0.00094, Accuracy = 99.780%
# Epoch 74 took 6m 41s
#   -> Epoch 74: Loss = 0.00066, Accuracy = 99.876%
# Epoch 75 took 6m 41s
#   -> Epoch 75: Loss = 0.00109, Accuracy = 99.739%
# Epoch 76 took 6m 40s
#   -> Epoch 76: Loss = 0.00098, Accuracy = 99.684%
# Epoch 77 took 6m 41s
#   -> Epoch 77: Loss = 0.00086, Accuracy = 99.808%
# Epoch 78 took 6m 41s
#   -> Epoch 78: Loss = 0.00058, Accuracy = 99.918%
# Epoch 79 took 6m 41s
#   -> Epoch 79: Loss = 0.00088, Accuracy = 99.767%
# Epoch 80 took 6m 40s
#   -> Epoch 80: Loss = 0.00083, Accuracy = 99.849%
# Epoch 81 took 6m 41s
#   -> Epoch 81: Loss = 0.00032, Accuracy = 99.973%
# Saving model based on loss. Loss: 0.00032 | Accuracy: 99.973%
# Epoch 82 took 6m 41s
#   -> Epoch 82: Loss = 0.00114, Accuracy = 99.643%
# Epoch 83 took 6m 40s
#   -> Epoch 83: Loss = 0.00069, Accuracy = 99.890%
# Epoch 84 took 6m 40s
#   -> Epoch 84: Loss = 0.00077, Accuracy = 99.835%
# Epoch 85 took 6m 41s
#   -> Epoch 85: Loss = 0.00076, Accuracy = 99.822%
# Epoch 86 took 6m 41s
#   -> Epoch 86: Loss = 0.00130, Accuracy = 99.725%
# Epoch 87 took 6m 40s
#   -> Epoch 87: Loss = 0.00053, Accuracy = 99.945%
# Epoch 88 took 6m 40s
#   -> Epoch 88: Loss = 0.00092, Accuracy = 99.725%
# Epoch 89 took 6m 41s
#   -> Epoch 89: Loss = 0.00080, Accuracy = 99.725%
# Epoch 90 took 6m 41s
#   -> Epoch 90: Loss = 0.00079, Accuracy = 99.794%
# Epoch 91 took 6m 41s
#   -> Epoch 91: Loss = 0.00064, Accuracy = 99.767%
# Epoch 92 took 6m 40s
#   -> Epoch 92: Loss = 0.00077, Accuracy = 99.808%
# Epoch 93 took 6m 41s
#   -> Epoch 93: Loss = 0.00150, Accuracy = 99.492%
# Epoch 94 took 6m 41s
#   -> Epoch 94: Loss = 0.00114, Accuracy = 99.712%
# Epoch 95 took 6m 40s
#   -> Epoch 95: Loss = 0.00038, Accuracy = 99.931%
# Epoch 96 took 6m 41s
#   -> Epoch 96: Loss = 0.00113, Accuracy = 99.629%
# Epoch 97 took 6m 41s
#   -> Epoch 97: Loss = 0.00076, Accuracy = 99.876%
# Epoch 98 took 6m 41s
#   -> Epoch 98: Loss = 0.00043, Accuracy = 99.973%
# Epoch 99 took 6m 40s
#   -> Epoch 99: Loss = 0.00096, Accuracy = 99.725%
# Training complete in 668m 56s

# %%
# Plotting accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(epoch_accuracies, label='Accuracy', color='blue')
plt.title("Training Accuracy")
plt.xlabel("Epoch Number")
plt.ylabel("Accuracy")

# Plotting loss
plt.subplot(1, 2, 2)
plt.plot(epoch_losses, label='Loss', color='red')
plt.title("Training Loss")
plt.xlabel("Epoch Number")
plt.ylabel("Loss")

plt.savefig(model_name_to_save.replace('.pth', '') + '-training_plot.png')

plt.show()

# %%
model_name_to_save
# Out:
# 'dino-models/unvalidated-dino-cls-b-surfaceproblem-tags-best.pth'
